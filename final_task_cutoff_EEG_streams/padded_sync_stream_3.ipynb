# %%
import pyxdf
from utils import sync_streams, combine_streams

# %% [markdown]
# Group 3:
#
# Task Begin: Immediately after Lasse says "We'll keep track of time"
# Task End: Immediately before Chris says "Think you're all set."
#
# CSL_LabPC
# Task Beginning UNIX timestamp: 1728395428.779 (171 sec in)
# Task End       UNIX timestamp: 1728399121.929 (3859 sec in)
#
# CSL_Laptop
# Task Beginning UNIX timestamp: 1728395428.779 (161 sec in)
#
# HCI_Lab1
# Task Beginning UNIX timestamp: 1728395428.779 (181 sec in)
#
# HCI_Lab2
# Task Beginning UNIX timestamp: 1728395452.904 (160 sec in)

# %%
group_num = 3
WPI_xdf_path = f"../Group {group_num}/HCILab1-Group3.xdf"
CSL_xdf_path = f"../Group {group_num}/CSL_08_10.xdf"
WPI_data_streams, WPI_header = pyxdf.load_xdf(WPI_xdf_path)
CSL_data_streams, CSL_header = pyxdf.load_xdf(CSL_xdf_path)
task_start_UNIX_times = {
    "OBS_HCILab1": 1728395428.779,
    "OBS_HCILab2": 1728395452.904,
    "OBS_CSL_Laptop": 1728395428.779,
    "OBS_CSL_LabPC": 1728395428.779
}
task_duration = 1728399121.929 - 1728395428.779
task_duration
# Out:
# Stream 3: Calculated effective sampling rate 15.2534 Hz is different from specified rate 30.0000 Hz.
# Stream 7: Calculated effective sampling rate -0.5664 Hz is different from specified rate 30.0000 Hz.
# Stream 8: Calculated effective sampling rate -45.3639 Hz is different from specified rate 250.0000 Hz.
# Stream 4: Calculated effective sampling rate -43.3404 Hz is different from specified rate 250.0000 Hz.
# Stream 6: Calculated effective sampling rate -0.1575 Hz is different from specified rate 30.0000 Hz.
# 3693.149999856949

# %%
# Sync the streams based on the shared stream's timestamp
streams = sync_streams(WPI_data_streams, CSL_data_streams, task_start_UNIX_times, task_duration)
combine_streams(group_num, streams)
# Out:
# length of EEG stream: 1077105
# start_EEG_index: 92948, end_EEG_index: 1016235
# padded_start_EEG_index: 90948, padded_end_EEG_index: 1018235
# For EEG Stream Unicorn_HCILab1, start cutoff index is 2000 and end cutoff index is 925287
#
# length of EEG stream: 1016073
# start_EEG_index: 106673, end_EEG_index: 1029960
# padded_start_EEG_index: 104673, padded_end_EEG_index: 1031960
# [cut short] For EEG Stream Unicorn_HCILab2, start cutoff index is 2000 and end cutoff index is 806727
#
# length of EEG stream: 1025374
# start_EEG_index: 81403, end_EEG_index: 1004690
# padded_start_EEG_index: 79403, padded_end_EEG_index: 1006690
# For EEG Stream Unicorn_CSL_Laptop, start cutoff index is 2000 and end cutoff index is 925287
#
# length of EEG stream: 1024097
# start_EEG_index: 81054, end_EEG_index: 1004341
# padded_start_EEG_index: 79054, padded_end_EEG_index: 1006341
# For EEG Stream Unicorn_CSL_LabPC, start cutoff index is 2000 and end cutoff index is 925287
# /Users/henryhuang/3rd Year/research/brain-hci/EEG-sync/virtual_env/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# Min: 166371.0
# Max: 238812.65625
# Mean: 203989.52006693798
# Standard Deviation: 15224.734944822305
